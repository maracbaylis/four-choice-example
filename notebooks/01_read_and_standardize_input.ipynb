# %% [markdown]
# # 01 Read and Standardize Four Choice TABS Input
#
# This notebook reads filled TABS workbooks and converts the form-style metadata and behavior tabs into flat tables. The parsing code lives in `src/four_choice_tabs_pipeline/` and `scripts/`.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent
sys.path.insert(0, str(PROJECT_ROOT / "src"))

from four_choice_tabs_pipeline.pipeline import example_input_dir, run_pipeline

INPUT_DIR = example_input_dir()
OUTDIR = PROJECT_ROOT / "outputs" / "notebook_example"
INPUT_DIR, OUTDIR

# %%
result = run_pipeline(INPUT_DIR, OUTDIR, make_png=False)

print(f"Input workbooks: {len(result.input_workbooks)}")
print(f"Metadata rows: {len(result.metadata)}")
print(f"Trial rows: {len(result.trials)}")
print(f"Session rows: {len(result.sessions)}")
print(f"Animal rows: {len(result.animals)}")
print(f"Weight rows: {len(result.weights)}")

# %%
result.metadata.head()

# %%
result.trials.head()

# %% [markdown]
# `animal_level_outputs.csv` is the main file for downstream plotting, PCA, and cross-lab merges. `trial_level.csv` keeps the full trial-by-trial readout.

# %%
result.animals.head()
