# %% [markdown]
# # 02 Quality Control and Plots
#
# This notebook reviews QC flags and writes the standard Four Choice figures.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent
sys.path.insert(0, str(PROJECT_ROOT / "src"))

from four_choice_tabs_pipeline.pipeline import example_input_dir, run_pipeline

OUTDIR = PROJECT_ROOT / "outputs" / "notebook_example"
result = run_pipeline(example_input_dir(), OUTDIR, make_png=True)
FIGURES = OUTDIR / "figures"

# %% [markdown]
# ## Metadata QC
#
# The QC table lists entries that need review. The parser does not silently fix these fields.

# %%
result.qc

# %%
result.qc.groupby(["field", "qc_flag"]).size().reset_index(name="n") if not result.qc.empty else "No QC flags"

# %% [markdown]
# ## Core Figures
#
# Figures are written to `outputs/notebook_example/figures/`.

# %%
sorted(path.name for path in FIGURES.glob("*.png"))

# %%
from IPython.display import Image, display

for figure_name in ["trials_to_criterion_mean_sem.png", "reversal_error_types.png", "pca_scores.png"]:
    figure_path = FIGURES / figure_name
    if figure_path.exists():
        display(Image(filename=str(figure_path)))
